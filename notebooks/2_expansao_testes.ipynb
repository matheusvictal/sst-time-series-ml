# %% [markdown]
# # Expansao de testes
# Esse notebook tem como objetivo:
# - gerar uma lista de pontos (séries sst) a serem analisados pelos benchmarks e SVR
# - comparar os resultados com estatísticas das séries

# %% [markdown]
# ## Intro

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import netCDF4 as nc
import xarray as xr
import netCDF4 as nc
from mpl_toolkits.basemap import Basemap
from mpl_toolkits.basemap import shiftgrid
import matplotlib.pyplot as plt
import pandas as pd
from random import randint
from tqdm import tqdm

# %%
from netuno import SSTHelper, SubserieDTW
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
fp = '../dados/sst.mnmean.nc'

# %%
ds = SSTHelper.load_dataset(fp)
df = SSTHelper.load_dataframe(ds)

# %%
split_date = '2021-12-01'

# %% [markdown]
# ## Geracao de Pontos
# ### Checagem
# Precisamos chegar se um ponto aleatório gerado é válido

# %%
def check_valid(df, lat, lon):
    ts = SSTHelper.get_sst_series(df, lat, lon).sst.to_list()
    if len(ts) == 0 or pd.isna(ts[0]):
        return False
    return True

# %%
check_valid(df, 0, -72) # o valor retornado deve ser falso
# Out:
# False

# %%
check_valid(df, -22, -72) # o valor retornado deve ser verdadeiro
# Out:
# False

# %%
def generate_even():
    return randint(-90, 90) * 2

# %% [markdown]
# ### Geraçao de pontos

# %%
list_points = set()
list_not_points = set()
n_points = 0

while n_points < 100:
    lat = generate_even() 
    lon = generate_even()
    while (lat, lon) in list_not_points or (lat, lon) in list_points or not check_valid(df, lat, lon):
        list_not_points.add((lat, lon))
        lat = generate_even()
        lon = generate_even()
    list_points.add((lat, lon))
    n_points += 1

# %%
invalid_count = 0
for point in list_points:
    if not check_valid(df, point[0], point[1]):
        invalid_count += 1

invalid_count
# Out:
# 0

# %%
list_points = list(list_points)
check_valid(df, list_points[0][0], list_points[0][1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 2
#       1 list_points = list(list_points)
# ----> 2 check_valid(df, list_points[0][0], list_points[0][1])
#
# IndexError: list index out of range

# %%
points_df = pd.DataFrame(list_points)

# %%
points_df.rename({0: 'lat', 1: 'lon'}, axis=1).to_csv('../dados/pontos.csv')

# %%
points_df
# Out:
#      0    1
# 0  -50   84
# 1   30  174
# 2   88    8
# 3  -66   32
# 4  -68  -20
# ..  ..  ...
# 95 -64   46
# 96 -12  -90
# 97  -2  158
# 98  34  172
# 99  12   50
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Reler os pontos salvos em csv

# %%
def read_list_points(filename):
    list_points = []
    with open(filename, 'r') as file:
        for line in file:
            line_split = line.split(',')
            try:
                list_points.append((int(line_split[1]), int(line_split[2])))
            except ValueError:
                pass
    return list_points

# %%
def read_results(filename):
    list_rmse = []
    list_mape = []
    with open(filename, 'r') as file:
        for line in file:
            line_split = line.split(',')
            try:
                list_rmse.append(float(line_split[1]))
                list_mape.append(float(line_split[2]))
            except ValueError:
                pass
    return [list_rmse, list_mape]

# %%
list_points = read_list_points('../dados/pontos.csv')

# %%
check_valid(df, list_points[35][0], list_points[35][1])
# Out:
# False

# %% [markdown]
# # Análise dos pontos recolhidos

# %% [markdown]
# ## Média das métricas de erro

# %%
list_approximate_entropy = []
list_dickey_fuller = []
list_benford_correlation = []
list_bin_entropy = []
list_std_deviation = []

sarima_results = []
svr_results = []

# %%
svr_results = read_results('../dados/svr_results.csv')
sarima_results = read_results('../dados/sarima_results.csv')
max(svr_results[1])
# Out:
# 4.287785737138222

# %%
measure_list = {
    'Approximate Entropy': list_approximate_entropy,
    'Benford Correlation': list_benford_correlation,
    'Bin Entropy': list_bin_entropy,
    'Standard Dev': list_std_deviation
}

error_metrics = {
    'RMSE': 0, 
    'MAPE': 1
}

method_list = {
    'SARIMA': sarima_results,
    'SVR': svr_results,
}

# %% [markdown]
# ### Resultado da média das métricas de erro

# %%
for method in method_list:
    print(f"======{method}======")
    for metric in error_metrics:
        print(f"Mean {metric}: {np.mean(method_list[method][error_metrics[metric]])}")
# Out:
# ======SARIMA======
# Mean RMSE: 0.46608967356777314
# Mean MAPE: 0.10142262232101876
# ======SVR======
# Mean RMSE: 0.7430425359337152
# Mean MAPE: 0.2754211184053565

# %% [markdown]
# ## Análise dos pontos utilizando características selecionadas

# %% [markdown]
# Vamos utilizar a biblioteca tsfresh para calcular estatísticas dos pontos recolhidos.
# As seguintes características serao consideradas:
# - Entropia aproximada
# - Dickey Fuller
# - Correlacao de Benford
# - Entropia em Bins
# - Desvio Padrao

# %%
from tsfresh.feature_extraction import feature_calculators
from scipy.stats import pearsonr, spearmanr

# %%
list_approximate_entropy = []
list_dickey_fuller = []
list_benford_correlation = []
list_bin_entropy = []
list_std_deviation = []

for point in tqdm(list_points):
    ts = SSTHelper.get_sst_series(df, point[0], point[1]).sst.to_numpy()
    list_approximate_entropy.append(feature_calculators.approximate_entropy(ts, 2, 3))
    # list_dickey_fuller.append(feature_calculators.augmented_dickey_fuller())
    list_benford_correlation.append(feature_calculators.benford_correlation(ts))
    list_bin_entropy.append(feature_calculators.binned_entropy(ts, 12))
    list_std_deviation.append(feature_calculators.standard_deviation(ts))
# Out:
#   0%|          | 0/100 [00:00<?, ?it/s]
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#   2%|▏         | 2/100 [00:00<00:06, 14.67it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#   4%|▍         | 4/100 [00:00<00:06, 15.34it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#   6%|▌         | 6/100 [00:00<00:05, 15.76it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#   8%|▊         | 8/100 [00:00<00:05, 15.84it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  10%|█         | 10/100 [00:00<00:05, 15.88it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  12%|█▏        | 12/100 [00:00<00:05, 15.81it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  14%|█▍        | 14/100 [00:00<00:05, 15.77it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  16%|█▌        | 16/100 [00:01<00:05, 15.88it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  18%|█▊        | 18/100 [00:01<00:05, 15.92it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  20%|██        | 20/100 [00:01<00:05, 15.96it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  22%|██▏       | 22/100 [00:01<00:04, 16.10it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  24%|██▍       | 24/100 [00:01<00:04, 16.11it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  26%|██▌       | 26/100 [00:01<00:04, 14.88it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  28%|██▊       | 28/100 [00:01<00:05, 13.85it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  30%|███       | 30/100 [00:01<00:05, 13.53it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  32%|███▏      | 32/100 [00:02<00:04, 14.21it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  34%|███▍      | 34/100 [00:02<00:04, 14.04it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  36%|███▌      | 36/100 [00:02<00:04, 14.22it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# ...
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  88%|████████▊ | 88/100 [00:06<00:00, 14.11it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  90%|█████████ | 90/100 [00:06<00:00, 14.42it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  92%|█████████▏| 92/100 [00:06<00:00, 14.26it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  94%|█████████▍| 94/100 [00:06<00:00, 13.97it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  96%|█████████▌| 96/100 [00:06<00:00, 13.44it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
#  98%|█████████▊| 98/100 [00:07<00:00, 13.24it/s]/home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:206: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:163: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean,
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:198: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:2363: RuntimeWarning: Mean of empty slice.
#   data_distribution = np.array([(x == n).mean() for n in range(1, 10)])
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/numpy/core/_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/feature_calculators.py:1677: RuntimeWarning: invalid value encountered in divide
#   probs = hist / x.size
# 100%|██████████| 100/100 [00:07<00:00, 13.86it/s]

# %%
list_std_deviation
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %% [markdown]
# ### Resultado de Correlaçao de Pearson com características selecionadas

# %%
for method in method_list:
    print(f"======{method}======")
    for measure in measure_list:
        print(measure)
        for metric in error_metrics:
            pearson, pvalue = spearmanr(method_list[method][error_metrics[metric]], measure_list[measure])
            print(f"(VS {metric}) Obtained {pearson:.3f} with p-value {pvalue:.3f}")
# Out:
# ======SARIMA======
# Approximate Entropy
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# Benford Correlation
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# Bin Entropy
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# Standard Dev
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# ======SVR======
# Approximate Entropy
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# Benford Correlation
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# Bin Entropy
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# Standard Dev
# (VS RMSE) Obtained nan with p-value nan
# (VS MAPE) Obtained nan with p-value nan
# /tmp/ipykernel_3942/3451267635.py:6: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   pearson, pvalue = spearmanr(method_list[method][error_metrics[metric]], measure_list[measure])

# %% [markdown]
# ## Análise dos pontos utilizando tsfresh

# %%
from tsfresh import extract_features, extract_relevant_features, select_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh.feature_extraction import ComprehensiveFCParameters

# %%
extraction_settings = ComprehensiveFCParameters()
list_features = []

for point in list_points:
    ts = pd.DataFrame(SSTHelper.get_sst_series(df, point[0], point[1]).sst)
    ts['id'] = 1
    X = extract_features(ts, 
                        column_id='id',
                        default_fc_parameters=extraction_settings,
                        # we impute = remove all NaN features automatically
                        impute_function=impute, disable_progressbar=True)
    list_features.append(X.to_numpy()[0])
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[57], line 7
#       5 ts = pd.DataFrame(SSTHelper.get_sst_series(df, point[0], point[1]).sst)
#       6 ts['id'] = 1
# ----> 7 X = extract_features(ts,
#       8                     column_id='id',
#       9                     default_fc_parameters=extraction_settings,
#      10                     # we impute = remove all NaN features automatically
#      11                     impute_function=impute, disable_progressbar=True)
#      12 list_features.append(X.to_numpy()[0])
#
# File ~/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/extraction.py:164, in extract_features(timeseries_container, default_fc_parameters, kind_to_fc_parameters, column_id, column_sort, column_kind, column_value, chunksize, n_jobs, show_warnings, disable_progressbar, impute_function, profile, profiling_filename, profiling_sorting, distributor, pivot)
#     161 else:
#     162     warnings.simplefilter("default")
# --> 164 result = _do_extraction(
#     165     df=timeseries_container,
#     166     column_id=column_id,
#     167     column_value=column_value,
#     168     column_kind=column_kind,
#     169     column_sort=column_sort,
#     170     n_jobs=n_jobs,
#     171     chunk_size=chunksize,
#     172     disable_progressbar=disable_progressbar,
#     173     show_warnings=show_warnings,
#     174     default_fc_parameters=default_fc_parameters,
#     175     kind_to_fc_parameters=kind_to_fc_parameters,
#     176     distributor=distributor,
#     177     pivot=pivot,
#     178 )
#     180 # Impute the result if requested
#     181 if impute_function is not None:
#
# File ~/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/feature_extraction/extraction.py:294, in _do_extraction(df, column_id, column_value, column_kind, column_sort, default_fc_parameters, kind_to_fc_parameters, n_jobs, chunk_size, disable_progressbar, show_warnings, distributor, pivot)
#     286     raise ValueError("the passed distributor is not an DistributorBaseClass object")
#     288 kwargs = dict(
#     289     default_fc_parameters=default_fc_parameters,
#     290     kind_to_fc_parameters=kind_to_fc_parameters,
#     291     show_warnings=show_warnings,
#     292 )
# --> 294 result = distributor.map_reduce(
#     295     _do_extraction_on_chunk,
#     296     data=data,
#     297     chunk_size=chunk_size,
#     298     function_kwargs=kwargs,
#     299 )
#     301 if not pivot:
#     302     return result
#
# File ~/Documents/sst-time-series-ml/venv/lib/python3.10/site-packages/tsfresh/utilities/distribution.py:225, in IterableDistributorBaseClass.map_reduce(self, map_function, data, function_kwargs, chunk_size, data_length)
#     222 map_kwargs = {"map_function": map_function, "kwargs": function_kwargs}
#     224 if hasattr(self, "progressbar_title"):
# --> 225     total_number_of_expected_results = math.ceil(data_length / chunk_size)
#     226     result = tqdm(
#     227         self.distribute(
#     228             _function_with_partly_reduce, chunk_generator, map_kwargs
#    (...)
#     232         disable=self.disable_progressbar,
#     233     )
#     234 else:
#
# ZeroDivisionError: division by zero

# %%
feature_names = list(X.columns)

# %%
n_features = len(list_features[0])

# %%
list_features = np.array(list_features).T
assert len(list_features) == n_features

# %%
dict_correlations = {}

# %%
for metric in error_metrics:
    metric_correlations = []
    metric_error_list = svr_results[error_metrics[metric]]
    for features in list_features:
        corr = pearsonr(features, metric_error_list)
        metric_correlations.append(corr)
    dict_correlations[metric] = metric_correlations
# Out:
# /home/vitor/Documents/sst-time-series-ml/venv/lib/python3.11/site-packages/scipy/stats/_stats_py.py:4781: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   warnings.warn(stats.ConstantInputWarning(msg))

# %%
df_correlations = pd.DataFrame(dict_correlations)

# %%
df_correlations.index = feature_names
df_correlations
# Out:
#                                                                                              RMSE  \
# sst__variance_larger_than_standard_deviation        (0.44731979994315746, 3.0729881762891283e-06)
# sst__has_duplicate_max                                 (-0.2237266202878018, 0.02524832714243999)
# sst__has_duplicate_min                                (-0.19308001819786774, 0.05426972831146174)
# sst__has_duplicate                                     (-0.06041214486123031, 0.5504593942983133)
# sst__sum_values                                       (0.26743164161825345, 0.007147912651909794)
# ...                                                                                           ...
# sst__permutation_entropy__dimension_5__tau_1         (0.3672714587770922, 0.00017073852592701697)
# sst__permutation_entropy__dimension_6__tau_1        (0.36822982942794863, 0.00016367568314930861)
# sst__permutation_entropy__dimension_7__tau_1        (0.36645049694987414, 0.00017701204284872207)
# sst__query_similarity_count__query_None__thresh...                                     (nan, nan)
# sst__mean_n_absolute_max__number_of_maxima_7         (0.36608678246247706, 0.0001798590710275413)
#
#                                                                                              MAPE
# sst__variance_larger_than_standard_deviation           (-0.0702630374779277, 0.48727103505926067)
# sst__has_duplicate_max                                 (-0.05919774523078725, 0.5585152661851898)
# sst__has_duplicate_min                                 (0.4686162851521978, 8.78286928239777e-07)
# sst__has_duplicate                                    (0.24586401758492657, 0.013674486852831232)
# sst__sum_values                                       (-0.3890989849187379, 6.30946593973488e-05)
# ...                                                                                           ...
# sst__permutation_entropy__dimension_5__tau_1         (-0.21833931785632546, 0.029084073610760968)
# sst__permutation_entropy__dimension_6__tau_1         (-0.22058485581835238, 0.027429100806286678)
# sst__permutation_entropy__dimension_7__tau_1         (-0.22170067461413456, 0.026636938860558085)
# sst__query_similarity_count__query_None__thresh...                                     (nan, nan)
# sst__mean_n_absolute_max__number_of_maxima_7        (-0.37528262646525656, 0.0001194512005474263)
#
# [788 rows x 2 columns]

# %%
df_correlations.sort_values(by='MAPE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/vitor/Documents/sst-time-series-ml/source/5_expansao_testes.ipynb Cell 48 line 1
# ----> <a href='vscode-notebook-cell:/home/vitor/Documents/sst-time-series-ml/source/5_expansao_testes.ipynb#X64sZmlsZQ%3D%3D?line=0'>1</a> df_correlations.sort_values(by='MAPE')
#
# NameError: name 'df_correlations' is not defined
